# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph, config=tf.ConfigProto(log_device_placement=True)) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6667 0.1151 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6466 0.1173 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5113 0.1153 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5970 0.1149 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5486 0.1141 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5546 0.1136 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5124 0.1135 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5361 0.1160 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5040 0.1183 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4249 0.1146 sec/batch
# Nearest to system: hedgehog, atat, ala, matched, apteryx, cropland, suprema, nonempty,
# Nearest to their: midge, philo, recognises, dealt, admit, rower, suburb, chemotherapy,
# Nearest to new: suit, mayors, services, meleon, jacobin, bluntly, lus, prostaglandins,
# Nearest to as: equitable, throwers, fun, philosophicus, performs, chao, pathologist, matchups,
# Nearest to and: eusebio, impostors, oppressor, intercepting, cyclically, significantly, cleft, hardwood,
# Nearest to into: spectacular, ephraim, intermarriages, southeastern, folio, vestments, vocation, boldsymbol,
# Nearest to he: grating, preliminary, drags, residue, huff, betrayal, kentish, expansive,
# Nearest to where: mens, sympathizers, horkheimer, survivors, argent, beasley, fils, anim,
# Nearest to bill: fca, contributory, dorian, peacekeeper, one, engulfed, stripe, lambar,
# Nearest to derived: safl, usenet, convened, duly, prisms, scraping, yak, alicia,
# Nearest to square: installments, luisa, havenworks, liebig, christological, priors, fasting, phagocytosis,
# Nearest to account: quenched, vampires, zseries, denham, latin, roger, kievan, usher,
# Nearest to gold: inverses, structure, petroleum, arma, birdwatching, garai, habash, plying,
# Nearest to paris: ghazni, spectrometry, escuela, marquess, parnassus, adb, senayan, warns,
# Nearest to recorded: heterosexuals, kru, copilot, streymoy, crustal, cartwright, demigods, velars,
# Nearest to behind: bartholomew, normalizing, heimskringla, macho, frantic, isshu, rave, jantz,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4923 0.1147 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3919 0.1138 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3312 0.1143 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2611 0.1141 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2174 0.1157 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1591 0.1137 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0981 0.1139 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0608 0.1136 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0037 0.1163 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9838 0.1155 sec/batch
# Nearest to system: atat, matched, hedgehog, threats, nonempty, ala, variously, serves,
# Nearest to their: admit, naturally, dealt, prolonged, decades, philo, recognises, period,
# Nearest to new: services, suit, home, contacts, town, mayors, lus, installed,
# Nearest to as: fun, equitable, players, performs, they, operators, equipped, pathologist,
# Nearest to and: central, eusebio, significantly, impostors, infinity, willing, oppressor, recognizable,
# Nearest to into: spectacular, southeastern, ephraim, colonial, door, folio, reconciliation, intermarriages,
# Nearest to he: preliminary, grating, expansive, residue, predictive, events, drags, clay,
# Nearest to where: less, mens, survivors, sympathizers, of, revenues, controversial, argent,
# Nearest to bill: fca, one, contributory, la, crow, congressional, dorian, british,
# Nearest to derived: usenet, convened, green, duly, export, proteins, prisms, safl,
# Nearest to square: luisa, installments, christological, havenworks, registered, stations, baptisms, fasting,
# Nearest to account: latin, vampires, roger, quenched, zseries, handle, fatal, deliberately,
# Nearest to gold: structure, inverses, petroleum, arma, arts, thin, hypnosis, best,
# Nearest to paris: arthur, causes, spectrometry, warns, rolfe, adb, star, aiding,
# Nearest to recorded: heterosexuals, televised, precarious, kru, copilot, considered, crustal, gott,
# Nearest to behind: bartholomew, normalizing, isshu, ask, heimskringla, hanseatic, commanders, n,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9305 0.1150 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9287 0.1138 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8849 0.1136 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8846 0.1138 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8143 0.1136 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8215 0.1141 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7912 0.1140 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7894 0.1139 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7785 0.1143 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7733 0.1151 sec/batch
# Nearest to system: matched, atat, hedgehog, nonempty, threats, ala, editing, variously,
# Nearest to their: dealt, admit, philo, naturally, bottleneck, atal, chemotherapy, recognises,
# Nearest to new: mayors, installed, jacobin, home, services, hoisted, contacts, suit,
# Nearest to as: fun, equitable, performs, they, players, operators, philosophicus, pathologist,
# Nearest to and: impostors, eusebio, significantly, intercepting, central, helps, wikis, oppressor,
# Nearest to into: spectacular, ephraim, southeastern, folio, intermarriages, colonial, reconciliation, door,
# Nearest to he: preliminary, grating, residue, expansive, betrayal, predictive, events, sa,
# Nearest to where: sympathizers, less, mens, vanished, helsinki, revenues, argent, survivors,
# Nearest to bill: fca, one, congressional, president, contributory, la, seymour, crow,
# Nearest to derived: usenet, convened, duly, proteins, green, export, misdemeanor, prisms,
# Nearest to square: installments, luisa, christological, registered, havenworks, baptisms, the, fasting,
# Nearest to account: vampires, latin, quenched, roger, zseries, fatal, denham, restrictive,
# Nearest to gold: structure, inverses, petroleum, tabloid, arma, accumulates, birdwatching, mil,
# Nearest to paris: arthur, causes, aiding, aunt, marquess, adb, star, rolfe,
# Nearest to recorded: heterosexuals, kru, descended, televised, streymoy, ambiguity, precarious, copilot,
# Nearest to behind: bartholomew, normalizing, hanseatic, heimskringla, ask, commanders, isshu, resides,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7798 0.1166 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7568 0.1139 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7339 0.1146 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7203 0.1136 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7127 0.1137 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6884 0.1135 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7016 0.1150 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7341 0.1142 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7339 0.1137 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6494 0.1151 sec/batch
# Nearest to system: atat, matched, hedgehog, nonempty, cropland, ala, picot, variously,
# Nearest to their: dealt, philo, admit, chemotherapy, terminates, recognises, naturally, manzarek,
# Nearest to new: jacobin, mayors, hoisted, installed, contacts, town, home, frankie,
# Nearest to as: equitable, fun, throwers, performs, criterion, pathologist, operators, karaoke,
# Nearest to and: eusebio, significantly, cyclically, helps, impostors, intercepting, central, oppressor,
# Nearest to into: spectacular, ephraim, folio, intermarriages, southeastern, vocation, door, colonial,
# Nearest to he: preliminary, residue, predictive, events, drags, concur, title, diverting,
# Nearest to where: sympathizers, mens, revenues, helsinki, vanished, argent, less, beasley,
# Nearest to bill: fca, one, president, congressional, seymour, july, contributory, jean,
# Nearest to derived: usenet, duly, convened, proteins, scraping, misdemeanor, yak, weevil,
# Nearest to square: installments, luisa, christological, havenworks, baptisms, the, informs, registered,
# Nearest to account: quenched, vampires, latin, zseries, roger, denham, fatal, restrictive,
# Nearest to gold: structure, inverses, petroleum, tabloid, arma, accumulates, perverse, mil,
# Nearest to paris: arthur, aunt, marquess, spectrometry, antebellum, aiding, adb, star,
# Nearest to recorded: heterosexuals, copilot, kru, cartwright, insular, streymoy, temporally, precarious,
# Nearest to behind: bartholomew, normalizing, hanseatic, commanders, heimskringla, ask, rave, macho,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6869 0.1196 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6683 0.1144 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6010 0.1168 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6075 0.1140 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6670 0.1141 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6140 0.1143 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5998 0.0815 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5408 0.1151 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5104 0.1134 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5116 0.1140 sec/batch
# Nearest to system: nonempty, matched, cropland, atat, hyperplane, directories, hedgehog, generalized,
# Nearest to their: dealt, chemotherapy, admit, philo, terminates, manzarek, recognises, kingly,
# Nearest to new: jacobin, hoisted, frankie, mayors, home, town, tx, bluntly,
# Nearest to as: equitable, fun, throwers, performs, marbury, criterion, karaoke, hesitant,
# Nearest to and: cyclically, oppressor, eusebio, intercepting, impostors, wikis, significantly, helps,
# Nearest to into: spectacular, ephraim, intermarriages, folio, tentatively, southeastern, vocation, colonial,
# Nearest to he: consorts, title, preliminary, concur, himself, dada, residue, drags,
# Nearest to where: sympathizers, helsinki, vanished, less, mens, survivors, revenues, argent,
# Nearest to bill: fca, president, crow, one, seymour, congressional, july, piero,
# Nearest to derived: usenet, duly, scraping, prisms, proteins, convened, weevil, misdemeanor,
# Nearest to square: installments, the, baptisms, christological, luisa, havenworks, aafc, showering,
# Nearest to account: quenched, vampires, denham, zseries, latin, roger, fatal, kievan,
# Nearest to gold: inverses, structure, petroleum, tabloid, accumulates, mil, allen, arma,
# Nearest to paris: arthur, marquess, aunt, spectrometry, one, financier, antebellum, aiding,
# Nearest to recorded: heterosexuals, insular, kru, copilot, cartwright, diagnosed, temporally, streymoy,
# Nearest to behind: bartholomew, normalizing, hanseatic, commanders, heimskringla, rave, frantic, ask,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4895 0.1218 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5001 0.1190 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4359 0.1137 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5192 0.1157 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4929 0.1145 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4787 0.1148 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4503 0.1152 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3839 0.1140 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4294 0.1136 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4291 0.1131 sec/batch
# Nearest to system: nonempty, cropland, gaming, atat, directories, hyperplane, generalized, subliminal,
# Nearest to their: dealt, admit, chemotherapy, philo, manzarek, amano, recognises, terminates,
# Nearest to new: jacobin, mayors, frankie, hoisted, tx, bluntly, home, town,
# Nearest to as: equitable, throwers, fun, performs, criterion, marbury, matchups, more,
# Nearest to and: impostors, cyclically, oppressor, intercepting, helps, wikis, eusebio, along,
# Nearest to into: spectacular, intermarriages, ephraim, folio, tentatively, colonial, southeastern, disinfectant,
# Nearest to he: himself, consorts, title, concur, preliminary, eldest, commit, dada,
# Nearest to where: mens, sympathizers, survivors, less, helsinki, hordes, thousandth, vanished,
# Nearest to bill: fca, crow, president, seymour, congressional, piero, jean, dorian,
# Nearest to derived: usenet, attenuated, proteins, duly, scraping, prisms, weevil, yak,
# Nearest to square: installments, the, island, showering, havenworks, stations, aafc, baptisms,
# Nearest to account: quenched, denham, vampires, latin, fatal, zseries, roger, sterilized,
# Nearest to gold: petroleum, structure, inverses, tabloid, accumulates, camra, birdwatching, beni,
# Nearest to paris: arthur, aunt, marquess, financier, antebellum, aiding, rolfe, merlot,
# Nearest to recorded: kru, heterosexuals, diagnosed, copilot, insular, cartwright, temporally, crustal,
# Nearest to behind: bartholomew, normalizing, commanders, heimskringla, hanseatic, rave, ask, frantic,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4387 0.1171 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4213 0.1160 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4286 0.1143 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4122 0.1137 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3951 0.1139 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4614 0.1137 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3811 0.1141 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3773 0.1150 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4031 0.1137 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3631 0.1135 sec/batch
# Nearest to system: atat, directories, nonempty, cropland, hedgehog, editing, hyperplane, crm,
# Nearest to their: dealt, chemotherapy, admit, amano, skill, philo, disadvantage, manzarek,
# Nearest to new: jacobin, mayors, frankie, tx, home, hoisted, bluntly, meleon,
# Nearest to as: throwers, equitable, performs, fun, criterion, matchups, marbury, hesitant,
# Nearest to and: oppressor, impostors, helps, wikis, intercepting, eusebio, cyclically, nyasa,
# Nearest to into: intermarriages, spectacular, ephraim, folio, disinfectant, tentatively, cataphract, vocation,
# Nearest to he: consorts, himself, title, dada, eldest, yakuza, prayer, commit,
# Nearest to where: thousandth, mens, helsinki, sympathizers, less, survivors, prod, anim,
# Nearest to bill: fca, crow, seymour, president, piero, hugo, lambar, rolland,
# Nearest to derived: usenet, attenuated, proteins, convened, incoherent, prisms, duly, scraping,
# Nearest to square: installments, the, showering, havenworks, island, aafc, liebig, metastable,
# Nearest to account: quenched, vampires, denham, latin, fatal, zseries, restrictive, sterilized,
# Nearest to gold: petroleum, camra, inverses, structure, beni, best, tabloid, accumulates,
# Nearest to paris: arthur, marquess, one, aiding, financier, aunt, merlot, rolfe,
# Nearest to recorded: kru, diagnosed, heterosexuals, copilot, crustal, cartwright, grenade, bomis,
# Nearest to behind: bartholomew, normalizing, commanders, hanseatic, heimskringla, reordering, frantic, ask,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3825 0.1170 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3963 0.1152 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3332 0.1173 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.4000 0.1139 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4040 0.1139 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3596 0.1137 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3641 0.1144 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3793 0.1132 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3214 0.1153 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3364 0.1161 sec/batch
# Nearest to system: directories, atat, cropland, gaming, editing, hedgehog, hyperplane, serves,
# Nearest to their: dealt, admit, chemotherapy, philo, skill, manzarek, insult, amano,
# Nearest to new: mayors, jacobin, frankie, merges, services, installed, home, bluntly,
# Nearest to as: throwers, equitable, performs, fun, more, hesitant, marbury, mania,
# Nearest to and: oppressor, impostors, cyclically, logistical, eusebio, wikis, central, tranquillity,
# Nearest to into: spectacular, intermarriages, ephraim, folio, cataphract, assimilated, tentatively, southeastern,
# Nearest to he: eldest, himself, consorts, his, dada, title, commit, roommate,
# Nearest to where: mens, survivors, sympathizers, thousandth, helsinki, vanished, minuit, progressives,
# Nearest to bill: fca, president, crow, seymour, congressional, piero, engulfed, communiqu,
# Nearest to derived: attenuated, usenet, inerrancy, proteins, greek, incoherent, divus, english,
# Nearest to square: installments, the, island, showering, havenworks, frac, m, ramming,
# Nearest to account: quenched, latin, denham, vampires, fatal, portugese, those, roger,
# Nearest to gold: petroleum, camra, beni, thin, structure, inverses, ice, accumulates,
# Nearest to paris: arthur, marquess, aunt, merlot, financier, aiding, rolfe, byron,
# Nearest to recorded: diagnosed, kru, copilot, heterosexuals, crustal, bomis, precarious, cartwright,
# Nearest to behind: bartholomew, normalizing, commanders, hanseatic, reordering, gis, frantic, quds,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3265 0.1163 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2819 0.1157 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3479 0.1156 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3774 0.1141 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3754 0.1143 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2946 0.1136 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2875 0.1140 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3395 0.1141 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2283 0.1138 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2960 0.1149 sec/batch
# Nearest to system: directories, jvm, cropland, gaming, hedgehog, editing, atat, serves,
# Nearest to their: dealt, admit, chemotherapy, philo, amano, manzarek, skill, insult,
# Nearest to new: mayors, merges, jacobin, meleon, frankie, installed, town, bluntly,
# Nearest to as: throwers, equitable, fun, performs, admixtures, more, hesitant, meteorites,
# Nearest to and: oppressor, impostors, cyclically, wikis, logistical, central, thelonious, interfaces,
# Nearest to into: intermarriages, spectacular, ephraim, assimilated, tentatively, southeastern, alves, cataphract,
# Nearest to he: his, himself, consorts, roommate, eldest, aristotelian, dada, betrayal,
# Nearest to where: mens, survivors, helsinki, thousandth, vanished, sympathizers, assaulted, hordes,
# Nearest to bill: fca, president, crow, seymour, congressional, piero, engulfed, communiqu,
# Nearest to derived: usenet, greek, attenuated, inerrancy, incoherent, proteins, divus, tremor,
# Nearest to square: installments, the, island, showering, aafc, inhabited, havenworks, ramming,
# Nearest to account: quenched, latin, denham, vampires, restrictive, leyden, kievan, roger,
# Nearest to gold: petroleum, camra, thin, beni, loon, isar, accumulates, tabloid,
# Nearest to paris: arthur, marquess, merlot, financier, aiding, sundance, rolfe, organist,
# Nearest to recorded: diagnosed, crustal, bomis, copilot, kru, suffragette, insular, grenade,
# Nearest to behind: bartholomew, normalizing, commanders, hanseatic, frantic, rave, gis, reordering,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2977 0.1172 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3086 0.1198 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3277 0.0524 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2735 0.1218 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2319 0.1185 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2221 0.1142 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2076 0.1139 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2172 0.1139 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2067 0.1139 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1914 0.1137 sec/batch
# Nearest to system: jvm, cropland, directories, serves, gaming, nonempty, hedgehog, lists,
# Nearest to their: dealt, chemotherapy, admit, skill, disadvantage, philo, manzarek, amano,
# Nearest to new: mayors, installed, tx, merges, meleon, jacobin, services, frankie,
# Nearest to as: throwers, equitable, meteorites, performs, admixtures, fun, matchups, more,
# Nearest to and: oppressor, wikis, cyclically, logistical, nabi, impostors, alloying, drumming,
# Nearest to into: intermarriages, spectacular, ephraim, southeastern, assimilated, tentatively, alves, frontage,
# Nearest to he: his, himself, eldest, consorts, reign, gave, ambitions, dada,
# Nearest to where: mens, survivors, anim, thousandth, naas, prod, helsinki, vineyard,
# Nearest to bill: fca, president, crow, congressional, seymour, engulfed, communiqu, lambar,
# Nearest to derived: usenet, proteins, attenuated, inerrancy, incoherent, scraping, greek, yak,
# Nearest to square: installments, the, island, aafc, rainforests, showering, ramming, m,
# Nearest to account: quenched, latin, vampires, greed, roger, portugese, denham, restrictive,
# Nearest to gold: petroleum, camra, lobsters, copper, beni, ice, thin, accumulates,
# Nearest to paris: merlot, arthur, financier, marquess, aiding, ghazni, organist, escuela,
# Nearest to recorded: diagnosed, crustal, copilot, bomis, kru, suffragette, shrugged, lipolysis,
# Nearest to behind: bartholomew, commanders, normalizing, hanseatic, mjh, jantz, reordering, rave,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2130 0.1150 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2001 0.1157 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2322 0.1203 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1397 0.1160 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1907 0.1142 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1613 0.1142 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.2036 0.1141 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1654 0.1167 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2166 0.1161 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1747 0.1238 sec/batch
# Nearest to system: jvm, hedgehog, serves, normalized, cropland, nonempty, lists, esso,
# Nearest to their: dealt, chemotherapy, skill, damp, admit, disadvantage, croatians, clerks,
# Nearest to new: tx, york, mayors, meleon, jacobin, bluntly, frankie, installed,
# Nearest to as: throwers, matchups, performs, equitable, more, marbury, speech, romance,
# Nearest to and: oppressor, interfaces, impostors, wikis, freefall, nabi, cyclically, transitive,
# Nearest to into: spectacular, intermarriages, alves, southeastern, ephraim, lesions, assimilated, frontage,
# Nearest to he: his, himself, eldest, consorts, prowess, aristotelian, gave, misinterpreted,
# Nearest to where: mens, thousandth, anim, prod, survivors, naas, hordes, vineyard,
# Nearest to bill: fca, president, crow, seymour, congressional, showgirls, breathable, lambar,
# Nearest to derived: attenuated, proteins, green, usenet, secretes, scraping, english, incoherent,
# Nearest to square: installments, the, island, ramming, frac, m, rainforests, showering,
# Nearest to account: quenched, latin, restrictive, greed, fatal, denham, those, kievan,
# Nearest to gold: petroleum, beni, camra, lobsters, copper, thin, loon, accumulates,
# Nearest to paris: merlot, aiding, marquess, arthur, financier, organist, ecuador, ghazni,
# Nearest to recorded: diagnosed, kru, copilot, crustal, bomis, suffragette, shrugged, lipolysis,
# Nearest to behind: commanders, bartholomew, normalizing, brushing, hanseatic, reordering, mjh, jantz,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.2161 0.1278 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2013 0.1155 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1865 0.1213 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1585 0.1260 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1936 0.1163 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2065 0.1143 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2020 0.1147 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1534 0.1144 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1532 0.1146 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1745 0.1142 sec/batch
# Nearest to system: normalized, hedgehog, jvm, serves, lists, cropland, esso, nonempty,
# Nearest to their: dealt, skill, chemotherapy, disadvantage, manzarek, philo, compliant, damp,
# Nearest to new: mayors, york, meleon, bluntly, tx, installed, jacobin, pisano,
# Nearest to as: throwers, admixtures, matchups, romance, meteorites, performs, progression, more,
# Nearest to and: oppressor, wikis, freefall, interfaces, impostors, alloying, dirge, tranquillity,
# Nearest to into: intermarriages, spectacular, assimilated, southeastern, ephraim, lesions, alves, frontage,
# Nearest to he: his, eldest, prowess, himself, consorts, preliminary, aristotelian, opry,
# Nearest to where: thousandth, prod, mens, anim, naas, vanished, survivors, deformations,
# Nearest to bill: fca, president, crow, seymour, congressional, showgirls, breathable, lambar,
# Nearest to derived: english, greek, incoherent, green, luxor, inerrancy, attenuated, proteins,
# Nearest to square: installments, the, ramming, frac, triangles, rainforests, showering, fountain,
# Nearest to account: quenched, greed, restrictive, those, leyden, roger, portugese, latin,
# Nearest to gold: petroleum, camra, lobsters, beni, copper, thin, accumulates, insubstantial,
# Nearest to paris: merlot, organist, ecuador, financier, arthur, escuela, marquess, aiding,
# Nearest to recorded: crustal, kru, bomis, copilot, diagnosed, televised, lipolysis, shrugged,
# Nearest to behind: commanders, bartholomew, normalizing, mjh, jantz, reordering, hanseatic, gis,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1769 0.1151 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1562 0.1157 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1551 0.1169 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1832 0.1176 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1455 0.1158 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1763 0.1144 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1643 0.1145 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1094 0.1141 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2106 0.1139 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2348 0.1142 sec/batch
# Nearest to system: jvm, hedgehog, normalized, serves, esso, atat, lists, cropland,
# Nearest to their: dealt, philo, clerks, croatians, skill, chemotherapy, stuarts, admit,
# Nearest to new: mayors, york, meleon, bluntly, tx, jacobin, frankie, installed,
# Nearest to as: throwers, romance, admixtures, matchups, philosophicus, marbury, tallahassee, more,
# Nearest to and: oppressor, tranquillity, dirge, thelonious, nursia, quelle, with, wikis,
# Nearest to into: intermarriages, ephraim, alves, assimilated, calvinistic, southeastern, spectacular, evict,
# Nearest to he: his, opry, prowess, himself, consorts, preliminary, reign, then,
# Nearest to where: mens, anim, survivors, naas, helsinki, hordes, thousandth, penn,
# Nearest to bill: fca, president, crow, congressional, seymour, showgirls, breathable, choreography,
# Nearest to derived: greek, abercorn, incoherent, circumscribed, inerrancy, proteins, uralic, secretes,
# Nearest to square: installments, the, ramming, frac, rainforests, demolished, island, showering,
# Nearest to account: quenched, greed, those, restrictive, latin, leyden, roger, portugese,
# Nearest to gold: petroleum, camra, lobsters, thin, beni, copper, insubstantial, isar,
# Nearest to paris: merlot, organist, ecuador, escuela, aiding, arthur, financier, sundance,
# Nearest to recorded: june, bomis, kru, alden, crustal, copilot, diagnosed, fortean,
# Nearest to behind: commanders, bartholomew, hanseatic, normalizing, jantz, mjh, gis, reordering,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2478 0.1157 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1507 0.1144 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1403 0.1149 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1292 0.1152 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0375 0.1151 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1627 0.1141 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1362 0.1142 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1224 0.1146 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1513 0.0187 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1344 0.1137 sec/batch
# Nearest to system: jvm, lists, hedgehog, esso, serves, luis, cropland, normalized,
# Nearest to their: dealt, skill, clerks, croatians, philo, damp, chemotherapy, disadvantage,
# Nearest to new: york, tx, installed, mayors, bluntly, retailer, meleon, disappearing,
# Nearest to as: throwers, romance, admixtures, more, meteorites, matchups, boney, tallahassee,
# Nearest to and: nyasa, interfaces, oppressor, freefall, with, dirge, central, nursia,
# Nearest to into: intermarriages, alves, assimilated, southeastern, bishkek, calvinistic, adhere, ephraim,
# Nearest to he: his, prowess, himself, opry, residue, misinterpreted, avid, then,
# Nearest to where: anim, survivors, naas, prod, mens, hordes, thousandth, deformations,
# Nearest to bill: fca, president, crow, congressional, seymour, showgirls, senate, lambar,
# Nearest to derived: secretes, incoherent, proteins, attenuated, luxor, gauss, abercorn, usenet,
# Nearest to square: the, installments, ramming, triangles, fountain, demolished, peninsulas, island,
# Nearest to account: quenched, those, greed, leyden, restrictive, roger, latin, denham,
# Nearest to gold: petroleum, lobsters, camra, copper, thin, beni, loon, insubstantial,
# Nearest to paris: merlot, organist, ecuador, escuela, aiding, financier, byron, sundance,
# Nearest to recorded: bomis, crustal, lipolysis, copilot, televised, june, kru, precarious,
# Nearest to behind: commanders, bartholomew, normalizing, hanseatic, jantz, mjh, catches, engrossed,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0875 0.1153 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0750 0.1140 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0605 0.1144 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0640 0.1160 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0664 0.1253 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0392 0.1166 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0895 0.1165 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1123 0.1172 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1391 0.1146 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0149 0.1184 sec/batch
# Nearest to system: jvm, hedgehog, lists, normalized, cropland, serves, luis, esso,
# Nearest to their: dealt, damp, skill, croatians, chemotherapy, clerks, disadvantage, dunmore,
# Nearest to new: york, tx, installed, bluntly, meleon, mayors, disappearing, retailer,
# Nearest to as: throwers, admixtures, more, matchups, meteorites, romance, boney, progression,
# Nearest to and: with, alloying, nyasa, oppressor, interfaces, freefall, wikis, impostors,
# Nearest to into: intermarriages, alves, southeastern, ephraim, assimilated, calvinistic, evict, lesions,
# Nearest to he: his, prowess, residue, himself, opry, consorts, avid, then,
# Nearest to where: anim, mens, survivors, naas, hordes, thousandth, deformations, the,
# Nearest to bill: fca, president, crow, seymour, showgirls, choreography, lambar, congressional,
# Nearest to derived: proteins, abercorn, luxor, secretes, circumscribed, incoherent, gauss, green,
# Nearest to square: the, installments, fountain, ramming, demolished, triangles, frac, peninsulas,
# Nearest to account: greed, quenched, those, portugese, restrictive, roger, leyden, accounts,
# Nearest to gold: petroleum, lobsters, thin, beni, copper, camra, loon, insubstantial,
# Nearest to paris: merlot, organist, escuela, ecuador, byron, financier, sundance, durrell,
# Nearest to recorded: bomis, lipolysis, televised, crustal, precarious, kru, june, of,
# Nearest to behind: commanders, bartholomew, normalizing, hanseatic, jantz, mjh, catches, engrossed,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0619 0.1149 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0404 0.1177 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0263 0.1153 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0571 0.1181 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0696 0.1193 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0843 0.1148 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0502 0.1154 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1045 0.1138 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0586 0.1138 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0338 0.1141 sec/batch
# Nearest to system: jvm, hedgehog, nonempty, cropland, normalized, luis, lists, characterizes,
# Nearest to their: dealt, damp, chemotherapy, skill, they, croatians, clerks, disadvantage,
# Nearest to new: york, tx, bluntly, meleon, uca, installed, mayors, dtv,
# Nearest to as: throwers, progression, admixtures, romance, distinct, boney, marbury, more,
# Nearest to and: oppressor, with, interfaces, alloying, nyasa, impostors, cyclically, transitive,
# Nearest to into: intermarriages, alves, assimilated, calvinistic, southeastern, cables, ephraim, folio,
# Nearest to he: his, prowess, opry, residue, avid, himself, consorts, misinterpreted,
# Nearest to where: anim, thousandth, mens, the, naas, prod, a, vineyard,
# Nearest to bill: fca, president, crow, seymour, showgirls, breathable, choreography, congressional,
# Nearest to derived: proteins, abercorn, luxor, circumscribed, english, gauss, secretes, green,
# Nearest to square: the, installments, ramming, fountain, demolished, triangles, dwellings, frac,
# Nearest to account: greed, those, quenched, restrictive, accounts, portugese, leyden, roger,
# Nearest to gold: petroleum, lobsters, camra, thin, beni, copper, loon, insubstantial,
# Nearest to paris: merlot, organist, escuela, ecuador, aiding, byron, durrell, sundance,
# Nearest to recorded: televised, bomis, crustal, kru, june, copilot, shrugged, precarious,
# Nearest to behind: commanders, bartholomew, normalizing, jantz, hanseatic, mjh, catches, engrossed,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0420 0.1185 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0911 0.1136 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0670 0.1138 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0722 0.1143 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0544 0.1163 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0683 0.1158 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0669 0.1187 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0476 0.1139 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1041 0.1138 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0816 0.1137 sec/batch
# Nearest to system: luis, jvm, hedgehog, normalized, esso, cropland, lists, shiite,
# Nearest to their: dealt, clerks, damp, they, chemotherapy, croatians, skill, philo,
# Nearest to new: york, meleon, tx, bluntly, mayors, uca, retailer, provision,
# Nearest to as: throwers, progression, romance, admixtures, philosophicus, tallahassee, distinct, matchups,
# Nearest to and: with, oppressor, nyasa, the, alloying, impostors, cyclically, dirge,
# Nearest to into: intermarriages, assimilated, alves, evict, calvinistic, southeastern, ephraim, bishkek,
# Nearest to he: his, prowess, residue, opry, avid, then, himself, ambitions,
# Nearest to where: mens, naas, the, anim, hordes, doke, a, survivors,
# Nearest to bill: fca, president, crow, congressional, seymour, showgirls, choreography, senate,
# Nearest to derived: proteins, abercorn, uralic, circumscribed, secretes, english, luxor, participles,
# Nearest to square: installments, the, ramming, fountain, demolished, triangles, showering, peninsulas,
# Nearest to account: greed, those, accounts, quenched, restrictive, portugese, leyden, allowable,
# Nearest to gold: petroleum, copper, lobsters, thin, camra, beni, insubstantial, titanium,
# Nearest to paris: merlot, organist, ecuador, escuela, gion, byron, durrell, aiding,
# Nearest to recorded: televised, bomis, kru, copilot, crustal, precarious, lipolysis, june,
# Nearest to behind: commanders, jantz, bartholomew, hanseatic, normalizing, mjh, catches, engrossed,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0426 0.1147 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0235 0.1140 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0227 0.1140 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0648 0.1139 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0463 0.1177 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1220 0.1186 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1566 0.1148 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0188 0.1138 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0654 0.1143 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0503 0.1134 sec/batch
# Nearest to system: lists, jvm, hedgehog, luis, normalized, nonempty, systems, esso,
# Nearest to their: dealt, chemotherapy, clerks, croatians, philo, skill, damp, dunmore,
# Nearest to new: york, meleon, mayors, uca, bluntly, ceres, retailer, ipswich,
# Nearest to as: throwers, admixtures, tallahassee, romance, for, progression, boney, distinct,
# Nearest to and: with, alloying, dirge, interfaces, nyasa, impostors, cyclically, agilent,
# Nearest to into: intermarriages, alves, assimilated, calvinistic, ephraim, bishkek, evict, ourense,
# Nearest to he: his, prowess, opry, residue, prospered, returned, himself, avid,
# Nearest to where: mens, naas, anim, the, hordes, prod, helsinki, vineyard,
# Nearest to bill: fca, president, crow, seymour, showgirls, congressional, choreography, senate,
# Nearest to derived: circumscribed, abercorn, uralic, ewald, inflectional, pronunciations, proteins, trilled,
# Nearest to square: installments, the, ramming, fountain, triangles, demolished, frac, peninsulas,
# Nearest to account: greed, those, accounts, roger, portugese, leyden, harbours, quenched,
# Nearest to gold: petroleum, copper, lobsters, thin, insubstantial, beni, camra, titanium,
# Nearest to paris: merlot, escuela, ecuador, organist, gion, durrell, aiding, byron,
# Nearest to recorded: bomis, televised, of, june, crustal, precarious, copilot, shrugged,
# Nearest to behind: commanders, bartholomew, jantz, normalizing, mjh, hanseatic, namath, engrossed,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9887 0.1148 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0137 0.1139 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0422 0.1150 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0362 0.1137 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.1005 0.1172 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0405 0.1015 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0078 0.1161 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9862 0.1143 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0122 0.1140 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9923 0.1139 sec/batch
# Nearest to system: hedgehog, jvm, lists, luis, plaza, systems, cropland, shiite,
# Nearest to their: chemotherapy, dealt, damp, croatians, skill, they, clerks, philo,
# Nearest to new: york, tx, meleon, uca, retailer, bluntly, september, ipswich,
# Nearest to as: throwers, romance, admixtures, distinct, meteorites, hunold, tallahassee, matchups,
# Nearest to and: with, alloying, nyasa, the, dirge, cyclically, interfaces, agilent,
# Nearest to into: intermarriages, alves, bishkek, assimilated, cables, calvinistic, ephraim, ourense,
# Nearest to he: his, prowess, residue, prospered, returned, himself, opry, then,
# Nearest to where: naas, anim, the, mens, hordes, vineyard, survivors, deformations,
# Nearest to bill: president, fca, crow, congressional, seymour, showgirls, choreography, breathable,
# Nearest to derived: ewald, circumscribed, abercorn, proteins, luxor, secretes, dickensian, filo,
# Nearest to square: installments, fountain, ramming, the, demolished, peninsulas, dwellings, triangles,
# Nearest to account: accounts, greed, those, roger, portugese, latin, leyden, expect,
# Nearest to gold: lobsters, petroleum, copper, thin, beni, insubstantial, camra, loon,
# Nearest to paris: merlot, ecuador, escuela, organist, gion, aiding, graeci, durrell,
# Nearest to recorded: televised, bomis, precarious, shrugged, june, of, copilot, crustal,
# Nearest to behind: bartholomew, commanders, mjh, jantz, normalizing, namath, hanseatic, catches,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9813 0.1143 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9195 0.1140 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0287 0.1134 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0192 0.1137 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0238 0.1134 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0118 0.1167 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9176 0.1212 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9745 0.1147 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9425 0.1137 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9811 0.1137 sec/batch
# Nearest to system: hedgehog, luis, jvm, plaza, shiite, systems, lists, vorticity,
# Nearest to their: dealt, they, damp, chemotherapy, skill, croatians, dunmore, clerks,
# Nearest to new: york, meleon, tx, uca, bluntly, indy, mayors, ceres,
# Nearest to as: throwers, for, distinct, in, boney, matchups, admixtures, more,
# Nearest to and: with, the, alloying, nyasa, cyclically, are, unsorted, of,
# Nearest to into: intermarriages, ephraim, calvinistic, assimilated, alves, adhere, harmonies, cables,
# Nearest to he: his, prowess, residue, returned, then, opry, himself, prayed,
# Nearest to where: mens, anim, the, hordes, fraternity, naas, helsinki, vineyard,
# Nearest to bill: fca, president, crow, showgirls, seymour, choreography, congressional, breathable,
# Nearest to derived: proteins, circumscribed, secretes, luxor, ewald, participles, abercorn, dickensian,
# Nearest to square: installments, fountain, ramming, the, peninsulas, demolished, triangles, showering,
# Nearest to account: accounts, greed, those, portugese, allowable, roger, leyden, latin,
# Nearest to gold: lobsters, petroleum, copper, beni, thin, insubstantial, loon, substantial,
# Nearest to paris: merlot, ecuador, escuela, gion, organist, aiding, durrell, graeci,
# Nearest to recorded: televised, of, bomis, precarious, shrugged, copilot, june, march,
# Nearest to behind: commanders, bartholomew, mjh, jantz, normalizing, namath, catches, hanseatic,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9959 0.1146 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0233 0.1140 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9791 0.1133 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0170 0.1136 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0323 0.1137 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9685 0.1150 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9987 0.1170 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0132 0.1185 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9647 0.1141 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0057 0.1140 sec/batch
# Nearest to system: hedgehog, jvm, systems, luis, normalized, shiite, plaza, lists,
# Nearest to their: dealt, they, skill, croatians, chemotherapy, damp, clerks, rrna,
# Nearest to new: york, uca, meleon, tx, bluntly, belknap, indy, mayors,
# Nearest to as: throwers, boney, distinct, progression, in, for, admixtures, matchups,
# Nearest to and: with, the, of, they, alloying, oppressor, impostors, in,
# Nearest to into: intermarriages, assimilated, alves, cables, ephraim, accessories, calvinistic, adhere,
# Nearest to he: his, prowess, opry, returned, residue, career, prospered, then,
# Nearest to where: anim, mens, naas, fraternity, doke, deformations, hordes, prod,
# Nearest to bill: fca, president, crow, showgirls, seymour, choreography, congressional, bed,
# Nearest to derived: circumscribed, abercorn, proteins, ewald, participles, luxor, secretes, dickensian,
# Nearest to square: installments, ramming, fountain, demolished, showering, the, tier, peninsulas,
# Nearest to account: greed, accounts, those, allowable, roger, expect, portugese, leyden,
# Nearest to gold: lobsters, copper, beni, petroleum, shaving, thin, insubstantial, loon,
# Nearest to paris: merlot, ecuador, gion, escuela, organist, aiding, durrell, le,
# Nearest to recorded: televised, precarious, of, bomis, shrugged, june, march, copilot,
# Nearest to behind: mjh, bartholomew, jantz, commanders, normalizing, electrophoresis, namath, hanseatic,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0054 0.1144 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9898 0.1136 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9979 0.1148 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0262 0.1155 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9838 0.1138 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9837 0.1140 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9884 0.1188 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9501 0.1156 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9773 0.1145 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9949 0.1138 sec/batch
# Nearest to system: jvm, shiite, luis, systems, hedgehog, atat, plaza, lists,
# Nearest to their: dealt, they, croatians, chemotherapy, damp, philo, clerks, and,
# Nearest to new: york, uca, meleon, bluntly, tx, provision, september, belknap,
# Nearest to as: throwers, boney, for, admixtures, distinct, progression, tallahassee, hunold,
# Nearest to and: with, the, of, in, alloying, nyasa, they, over,
# Nearest to into: assimilated, intermarriages, alves, calvinistic, cables, adhere, urgently, homogeneous,
# Nearest to he: his, prowess, residue, prospered, opry, career, returned, foxe,
# Nearest to where: doke, hordes, anim, naas, mens, the, fraternity, deformations,
# Nearest to bill: fca, president, crow, seymour, congressional, showgirls, choreography, bed,
# Nearest to derived: circumscribed, proteins, participles, abercorn, secretes, luxor, inflectional, ewald,
# Nearest to square: installments, ramming, fountain, demolished, showering, tier, peninsulas, the,
# Nearest to account: accounts, greed, those, roger, allowable, leyden, portugese, latin,
# Nearest to gold: lobsters, copper, beni, thin, petroleum, shaving, insubstantial, pence,
# Nearest to paris: merlot, escuela, ecuador, organist, gion, le, durrell, aiding,
# Nearest to recorded: televised, of, precarious, islam, bomis, shrugged, copilot, june,
# Nearest to behind: mjh, jantz, commanders, normalizing, bartholomew, electrophoresis, namath, gis,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9598 0.1150 sec/batch
# ...
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8327 0.1132 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7907 0.1140 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8219 0.1155 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8381 0.1146 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8884 0.1131 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8267 0.1132 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8549 0.1132 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9101 0.1132 sec/batch
# Nearest to system: systems, jvm, qdos, hedgehog, shiite, plaza, vorticity, in,
# Nearest to their: they, and, with, own, to, as, all, have,
# Nearest to new: york, uca, macmillan, press, codepages, feelgood, september, unitas,
# Nearest to as: for, in, the, of, known, and, a, be,
# Nearest to and: with, the, of, in, a, as, by, over,
# Nearest to into: by, same, this, intermarriages, that, the, cables, adhere,
# Nearest to he: his, career, returned, opry, prowess, him, then, himself,
# Nearest to where: the, ddot, deformations, in, fraternity, to, anim, received,
# Nearest to bill: fca, seymour, president, veto, potok, kucinich, crow, showgirls,
# Nearest to derived: derives, circumscribed, secretes, moloch, dickensian, filo, participles, ewald,
# Nearest to square: installments, ramming, showering, demolished, priors, fountain, streets, minaret,
# Nearest to account: greed, accounts, denham, allowable, fatal, havenco, those, chemicals,
# Nearest to gold: silver, shaving, medals, copper, donates, medal, loon, camra,
# Nearest to paris: merlot, pour, gion, aiding, graeci, le, parnassus, sur,
# Nearest to recorded: televised, precarious, bomis, band, thunderstorms, copilot, of, leases,
# Nearest to behind: namath, mjh, electrophoresis, outward, elongated, goal, reordering, jantz,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8654 0.1142 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8422 0.1129 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8633 0.1139 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8274 0.1135 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8779 0.1144 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8902 0.1167 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8564 0.1142 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8055 0.1128 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8720 0.1134 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8595 0.1132 sec/batch
# Nearest to system: systems, qdos, jvm, shiite, vorticity, hedgehog, plaza, rockets,
# Nearest to their: they, and, with, to, own, as, by, others,
# Nearest to new: york, uca, press, macmillan, september, codepages, bantam, frankie,
# Nearest to as: for, the, of, known, and, in, a, both,
# Nearest to and: with, the, of, in, a, as, to, over,
# Nearest to into: the, by, intermarriages, this, same, ourense, adhere, harmonies,
# Nearest to he: his, returned, career, prowess, opry, studied, residue, prospered,
# Nearest to where: the, deformations, ddot, vineyard, to, fraternity, ndwandwe, in,
# Nearest to bill: fca, veto, seymour, president, potok, criminalization, kucinich, crow,
# Nearest to derived: derives, moloch, abercorn, circumscribed, sizeable, dickensian, participles, filo,
# Nearest to square: installments, showering, ramming, priors, triumph, cambridge, minaret, motherboards,
# Nearest to account: greed, accounts, denham, allowable, havenco, chemicals, imager, camouflaged,
# Nearest to gold: silver, shaving, copper, donates, medals, loon, camra, chromite,
# Nearest to paris: merlot, gion, pour, le, sur, graeci, parnassus, aiding,
# Nearest to recorded: televised, precarious, bomis, of, thunderstorms, copilot, march, mixes,
# Nearest to behind: namath, mjh, elongated, jantz, electrophoresis, outward, reordering, goal,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8762 0.1145 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8836 0.1138 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8213 0.1138 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8288 0.1131 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8902 0.1136 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8175 0.1179 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9541 0.1156 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9017 0.1134 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9344 0.1133 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8271 0.1141 sec/batch
# Nearest to system: systems, qdos, shiite, jvm, plaza, and, hedgehog, atat,
# Nearest to their: they, and, to, with, others, own, in, were,
# Nearest to new: york, macmillan, press, uca, abstaining, codepages, september, harmonium,
# Nearest to as: the, for, of, and, known, a, in, with,
# Nearest to and: with, in, the, of, a, as, to, their,
# Nearest to into: the, by, intermarriages, of, that, same, this, turn,
# Nearest to he: his, returned, career, prowess, opry, him, studied, then,
# Nearest to where: ddot, the, anim, vineyard, deformations, boldface, fraternity, to,
# Nearest to bill: fca, veto, president, seymour, potok, kucinich, criminalization, bed,
# Nearest to derived: derives, abercorn, moloch, dickensian, circumscribed, inflectional, raisins, sizeable,
# Nearest to square: installments, showering, ramming, priors, triumph, cambridge, tier, motherboards,
# Nearest to account: greed, accounts, denham, havenco, allowable, camouflaged, multiplication, melanippe,
# Nearest to gold: silver, shaving, donates, medals, copper, medal, camra, insubstantial,
# Nearest to paris: pour, gion, merlot, le, aiding, sur, graeci, parnassus,
# Nearest to recorded: televised, precarious, of, recording, copilot, records, march, band,
# Nearest to behind: namath, mjh, elongated, outward, electrophoresis, jantz, nevado, goryeo,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7748 0.1143 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8603 0.1136 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7668 0.1137 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8729 0.1138 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8408 0.1133 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8113 0.1143 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9148 0.0550 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8386 0.1149 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8411 0.1140 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8221 0.1135 sec/batch
# Nearest to system: systems, jvm, plaza, vorticity, qdos, shiite, regulars, hedgehog,
# Nearest to their: they, and, own, others, with, were, as, to,
# Nearest to new: york, press, uca, macmillan, september, abstaining, harmonium, theatrum,
# Nearest to as: the, of, for, known, and, in, a, although,
# Nearest to and: with, the, in, of, to, as, by, a,
# Nearest to into: the, same, this, that, by, intermarriages, ourense, a,
# Nearest to he: his, returned, career, him, was, himself, prowess, residue,
# Nearest to where: the, to, anim, in, deformations, at, ddot, vineyard,
# Nearest to bill: fca, veto, seymour, president, potok, kucinich, crow, draft,
# Nearest to derived: derives, dickensian, abercorn, moloch, ewald, circumscribed, filo, sizeable,
# Nearest to square: installments, ramming, showering, minaret, priors, cambridge, demolished, area,
# Nearest to account: accounts, greed, havenco, melanippe, denham, allowable, fatal, lud,
# Nearest to gold: shaving, silver, medals, donates, copper, medal, camra, loon,
# Nearest to paris: merlot, gion, pour, le, aiding, parnassus, graeci, france,
# Nearest to recorded: televised, precarious, thunderstorms, of, copilot, march, band, mixes,
# Nearest to behind: namath, mjh, elongated, jantz, outward, goal, reordering, goryeo,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8519 0.1143 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8161 0.1185 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8302 0.1303 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8032 0.1333 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8827 0.1282 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8492 0.1304 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8798 0.1330 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7468 0.1319 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8088 0.1311 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7945 0.1257 sec/batch
# Nearest to system: systems, in, vorticity, and, jvm, qdos, plaza, shiite,
# Nearest to their: they, and, as, own, with, were, others, to,
# Nearest to new: york, uca, macmillan, press, bantam, abstaining, harmonium, feelgood,
# Nearest to as: the, for, of, in, and, known, a, which,
# Nearest to and: with, the, in, of, a, as, to, are,
# Nearest to into: the, this, by, intermarriages, same, that, turn, hometown,
# Nearest to he: his, returned, career, him, opry, prowess, residue, himself,
# Nearest to where: the, to, at, anim, and, in, fraternity, deformations,
# Nearest to bill: fca, veto, seymour, crow, criminalization, potok, showgirls, president,
# Nearest to derived: derives, moloch, dickensian, ewald, sizeable, circumscribed, abercorn, term,
# Nearest to square: installments, ramming, showering, cambridge, priors, minaret, area, streets,
# Nearest to account: greed, accounts, allowable, denham, tanker, expect, multiplication, havenco,
# Nearest to gold: silver, shaving, donates, medals, copper, loon, medal, camra,
# Nearest to paris: merlot, gion, pour, graeci, parnassus, le, mathilde, aiding,
# Nearest to recorded: televised, precarious, thunderstorms, march, record, band, records, copilot,
# Nearest to behind: namath, mjh, elongated, outward, jantz, passer, goryeo, electrophoresis,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7415 0.1295 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8164 0.1284 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8586 0.1233 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8214 0.1253 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8116 0.1305 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8886 0.1272 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8549 0.1293 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8042 0.1135 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8149 0.1141 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8057 0.1138 sec/batch
# Nearest to system: systems, plaza, in, vorticity, qdos, shiite, jvm, rockets,
# Nearest to their: they, and, with, own, as, to, others, such,
# Nearest to new: york, press, uca, macmillan, bantam, scribner, frankie, harmonium,
# Nearest to as: the, for, of, and, in, known, a, although,
# Nearest to and: with, the, in, of, as, to, a, for,
# Nearest to into: the, by, same, this, that, intermarriages, turn, ourense,
# Nearest to he: his, career, returned, opry, then, prowess, him, sensei,
# Nearest to where: the, to, at, fraternity, ddot, and, anim, deformations,
# Nearest to bill: fca, veto, seymour, crow, showgirls, criminalization, bed, president,
# Nearest to derived: derives, abercorn, dickensian, moloch, term, ewald, sizeable, filo,
# Nearest to square: installments, ramming, showering, priors, triumph, cambridge, minaret, epping,
# Nearest to account: greed, havenco, allowable, denham, fatal, tanker, expect, imager,
# Nearest to gold: shaving, silver, medals, donates, medal, copper, camra, loon,
# Nearest to paris: pour, merlot, gion, le, parnassus, france, graeci, aiding,
# Nearest to recorded: televised, precarious, march, record, thunderstorms, band, of, bomis,
# Nearest to behind: namath, mjh, elongated, outward, jantz, goal, electrophoresis, passer,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8856 0.1144 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8075 0.1140 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8112 0.1142 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8535 0.1150 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8772 0.1147 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8403 0.1154 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8239 0.1166 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8434 0.1139 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8091 0.1138 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8238 0.1139 sec/batch
# Nearest to system: systems, and, in, plaza, of, qdos, shiite, jvm,
# Nearest to their: they, and, as, own, to, with, them, these,
# Nearest to new: york, press, uca, macmillan, codepages, september, scribner, in,
# Nearest to as: the, for, of, and, in, a, known, although,
# Nearest to and: with, the, in, of, to, a, as, which,
# Nearest to into: the, this, by, same, turn, of, intermarriages, that,
# Nearest to he: his, career, returned, opry, him, prowess, himself, residue,
# Nearest to where: the, at, in, and, to, anim, ddot, deformations,
# Nearest to bill: veto, fca, seymour, president, enforceable, kucinich, draft, bed,
# Nearest to derived: derives, abercorn, sizeable, moloch, dickensian, inflectional, term, sanctified,
# Nearest to square: installments, ramming, priors, showering, minaret, triumph, madhava, cambridge,
# Nearest to account: greed, accounts, describes, havenco, denham, flung, expect, imager,
# Nearest to gold: donates, silver, shaving, medals, copper, medal, camra, loon,
# Nearest to paris: merlot, gion, pour, le, parnassus, graeci, aiding, vien,
# Nearest to recorded: televised, precarious, records, of, bomis, march, record, thunderstorms,
# Nearest to behind: namath, mjh, elongated, outward, jantz, situated, electrophoresis, ivanhoe,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8554 0.1148 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8315 0.1137 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9133 0.1136 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8892 0.1135 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8860 0.1140 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8408 0.1149 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7901 0.1151 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8327 0.1139 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7484 0.1138 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8759 0.1148 sec/batch
# Nearest to system: systems, and, plaza, in, jvm, qdos, vorticity, regulars,
# Nearest to their: they, and, as, own, to, them, with, these,
# Nearest to new: york, press, macmillan, september, uca, codepages, frankie, harmonium,
# Nearest to as: the, for, of, and, in, a, such, known,
# Nearest to and: with, in, the, of, as, a, to, by,
# Nearest to into: the, same, by, this, a, turn, of, hometown,
# Nearest to he: his, career, returned, opry, himself, him, prowess, residue,
# Nearest to where: the, in, to, ddot, anim, fraternity, received, at,
# Nearest to bill: veto, fca, seymour, draft, bed, president, potok, crow,
# Nearest to derived: derives, abercorn, sizeable, sanctified, dickensian, substantial, moloch, term,
# Nearest to square: installments, ramming, showering, minaret, priors, polymaths, triumph, motherboards,
# Nearest to account: accounts, greed, denham, flung, describes, allowable, tanker, havenco,
# Nearest to gold: donates, silver, medals, shaving, medal, copper, loon, camra,
# Nearest to paris: gion, merlot, pour, graeci, aiding, le, parnassus, mathilde,
# Nearest to recorded: televised, precarious, records, recording, record, thunderstorms, band, leases,
# Nearest to behind: namath, mjh, elongated, jantz, outward, depraved, ivanhoe, kundalini,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8368 0.1145 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8246 0.1134 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
